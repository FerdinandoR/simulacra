# %%
import os
import re
import pandas as pd
import pickle

# 1) Load the embeddings CSV from project root
project_root = (
    os.path.abspath(os.path.join(os.getcwd(), '..')) 
    if os.path.basename(os.getcwd()) == 'notebooks' 
    else os.getcwd()
)
csv_filename = 'embeddings_GSE42861_mult2_nyears10_seed42.csv'
csv_path = os.path.join(project_root, csv_filename)

# Check if filtered data is already cached
cache_file = os.path.join(project_root, 'data', 'filtered_embeddings.pkl')
os.makedirs(os.path.dirname(cache_file), exist_ok=True)

if os.path.exists(cache_file):
    print("Loading filtered embeddings from cache...")
    with open(cache_file, 'rb') as f:
        filtered_df = pickle.load(f)
    print("Filtered dataframe head (index already normalized to GSM):")
    display(filtered_df.head())
else:
    print("Processing embeddings CSV (this may take a while)...")
    
    if not os.path.isfile(csv_path):
        raise FileNotFoundError(f"CSV file not found at: {csv_path}")

    # TODO: the embeddings produced with pythae will always have such an index, so I should simplify this bit and just assume that the first column is the index
    # Use index column if present (first column often is an index for embeddings)
    # We'll try to infer: if the first column has non-numeric values typical of sample IDs, set it as index
    _df = pd.read_csv(csv_path)
    first_col_name = str(_df.columns[0])
    if first_col_name.lower() in {'index', 'id', 'sample_id'} or _df[first_col_name].dtype == 'object':
        df = pd.read_csv(csv_path, index_col=0)
    else:
        df = _df

    # 2) Normalize index to pure GSM accession (GSM\d+) and keep rows with a GSM
    # Convert index to string in case it's not
    df.index = df.index.map(str)
    # Extract GSM ids from index
    gsm_index = df.index.to_series().str.extract(r"(GSM\d+)", expand=False)
    # Keep only rows that have a GSM and set it as the index
    df = df.loc[gsm_index.notna()].copy()
    df.index = gsm_index[gsm_index.notna()]
    # Use the normalized dataframe for downstream steps
    filtered_df = df

    # Print head of the normalized dataframe
    print("Filtered dataframe head (index normalized to GSM):")
    display(filtered_df.head())
    
    # Save to cache
    print("Saving filtered embeddings to cache...")
    with open(cache_file, 'wb') as f:
        pickle.dump(filtered_df, f)

# 3) Load metadata via biolearn for the accession number parsed from the filename
# We assume the filename contains an accession like GSE12345; extract it.
accession_match = re.search(r"(GSE\d+)", csv_filename, flags=re.IGNORECASE)
accession = accession_match.group(1).upper() if accession_match else None

print("\nAccession parsed from filename:", accession)

# Check if metadata is already cached
metadata_cache_file = os.path.join(project_root, 'data', f'metadata_{accession}.pkl')

if os.path.exists(metadata_cache_file):
    print("Loading metadata from cache...")
    with open(metadata_cache_file, 'rb') as f:
        metadata_df = pickle.load(f)
    print("\nBiolearn metadata (head):")
    display(metadata_df.head())
    print("Metadata shape:", metadata_df.shape)
else:
    print("Loading metadata via biolearn (this may take a while)...")
    # 3) Load metadata via biolearn using simulacra.utils helpers
    from simulacra.utils import load_acc

    if accession is None:
        print("\nCould not parse a GSE accession from the filename; cannot load metadata.")
    else:
        try:
            data = load_acc(accession)
            metadata_df = data.metadata
            print("\nBiolearn metadata (head):")
            display(metadata_df.head())
            print("Metadata shape:", metadata_df.shape)
            
            # Save to cache
            print("Saving metadata to cache...")
            with open(metadata_cache_file, 'wb') as f:
                pickle.dump(metadata_df, f)
        except Exception as e:
            print("\nFailed to load metadata via biolearn/DataLibrary.")
            print("Reason:", repr(e))
# Out:
# Processing embeddings CSV (this may take a while)...
# Filtered dataframe head (index normalized to GSM):
#                emb_0     emb_1     emb_2     emb_3     emb_4     emb_5  \
# id
# GSM1051881 -0.001305  0.000200  0.001953 -0.002734  0.000159  0.001963
# GSM1051977  0.000590 -0.001857 -0.002502  0.002780 -0.001102 -0.001300
# GSM1052156  0.000802  0.004568  0.006876  0.001612 -0.002390  0.007284
# GSM1051741 -0.003565 -0.002953  0.000190 -0.004830  0.000698  0.003887
# GSM1051729  0.003396  0.000118 -0.000663  0.006748 -0.002380  0.002448
#
#                emb_6     emb_7     emb_8     emb_9  ...   emb_502   emb_503  \
# id                                                  ...
# GSM1051881 -0.000451 -0.005499  0.002583 -0.003466  ...  0.001220 -0.001565
# GSM1051977 -0.001350 -0.001323 -0.004603  0.001543  ... -0.000943  0.004626
# GSM1052156 -0.002453 -0.001633 -0.000554 -0.005257  ... -0.003316  0.002482
# GSM1051741 -0.004089 -0.004348  0.004465 -0.001062  ...  0.001848 -0.001194
# GSM1051729 -0.000839 -0.004645 -0.002241 -0.002708  ... -0.001094 -0.001565
#
#              emb_504   emb_505   emb_506   emb_507   emb_508   emb_509  \
# id
# GSM1051881 -0.005460 -0.002010 -0.004003  0.000767  0.000756 -0.003183
# GSM1051977 -0.001879 -0.000146  0.002117 -0.001068  0.001165 -0.001526
# GSM1052156 -0.001748  0.001319 -0.003379 -0.003346 -0.000742  0.000892
# GSM1051741  0.002220  0.000575 -0.002808  0.000373 -0.001696 -0.004429
# GSM1051729  0.001197 -0.001617  0.000472  0.005212 -0.000733 -0.000215
#
#              emb_510   emb_511
# id
# GSM1051881  0.001178 -0.002373
# GSM1051977  0.000915  0.000664
# GSM1052156 -0.001373 -0.003123
# GSM1051741 -0.000311 -0.000372
# GSM1051729  0.001592  0.002087
#
# [5 rows x 512 columns]
# Saving filtered embeddings to cache...
#
# Accession parsed from filename: GSE42861
# Loading metadata via biolearn (this may take a while)...
#
# Biolearn metadata (head):
#                          disease   age  sex  smoking
# id
# GSM1051525  rheumatoid arthritis  67.0    1  current
# GSM1051526  rheumatoid arthritis  49.0    1  current
# GSM1051527  rheumatoid arthritis  53.0    1       ex
# GSM1051528  rheumatoid arthritis  62.0    1  current
# GSM1051529  rheumatoid arthritis  33.0    1    never
# Metadata shape: (689, 4)
# Saving metadata to cache...

# %%
import pandas as pd
import pickle
import os

# Check if merged data is already cached
project_root = os.path.abspath(os.path.join(os.getcwd(), '..')) if os.path.basename(os.getcwd()) == 'notebooks' else os.getcwd()
merge_cache_file = os.path.join(project_root, 'data', 'merged_df.pkl')

if os.path.exists(merge_cache_file):
    print("Loading merged dataframe from cache...")
    with open(merge_cache_file, 'rb') as f:
        merged_df = pickle.load(f)
    print("Merged dataframe (with 'disease' as first column):")
    display(merged_df)
else:
    print("Merging embeddings with metadata (this may take a while)...")
    
    # Validate prerequisites
    if 'filtered_df' not in globals() or 'metadata_df' not in globals():
        raise RuntimeError("Required variables not found. Ensure the first cell"
            " was executed (defines 'filtered_df' and 'metadata_df').")

    # Embeddings index is already normalized to GSM in the first cell
    # Ensure no missing GSMs remain
    if (
        pd.Series(filtered_df.index.astype(str)).str.match(r"^GSM\d+$").
        pipe(lambda s: ~s).any()
    ):
        raise ValueError("Embeddings index must be normalized to GSM "
            "before merging.")

    # Prepare metadata index to be GSM-based
    mdf = metadata_df.copy()
    # TODO: this might be slightly redundant, but I'm not sure: could this be
    # the same if I delete both the "not" and the "case=False"?
    if not (mdf.index.astype(str).str.
        contains(r"^GSM\d+$", case=False, regex=True).all()
    ):
        # Try common columns that may hold GSM accessions
        candidate_cols = [
            c for c in mdf.columns if str(c).lower() in 
            {"gsm", "geo_accession"}
        ]
        if candidate_cols:
            mdf = mdf.set_index(candidate_cols[0])
        else:
            # Try to extract GSM from any string-like column heuristically
            found_index = None
            for c in mdf.columns:
                if pd.api.types.is_string_dtype(mdf[c]):
                    gsm_series = mdf[c].astype(str).str.extract(
                        r"(GSM\d+)", 
                        expand=False
                    )
                    if gsm_series.notna().all():
                        mdf = mdf.set_index(gsm_series)
                        found_index = c
                        break
            if found_index is None:
                raise ValueError("Could not identify a GSM-based index in"
                " metadata. Expected index or a column like 'gsm' or"
                " 'geo_accession'.")

    # Locate the disease column (case-insensitive match on name 'disease')
    disease_col_candidates = [
        c for c in mdf.columns if str(c).lower() == 'disease'
    ]
    if not disease_col_candidates:
        raise ValueError("'disease' column not found in metadata.")
    disease_col = disease_col_candidates[0]

    # Build aligned disease series for the filtered embeddings using GSM 
    # index directly
    disease_by_gsm = mdf[disease_col]
    disease_for_emb = pd.Series(
        filtered_df.index.astype(str), 
        index=filtered_df.index).map(disease_by_gsm)

    # Create merged dataframe with disease as the first non-index column
    merged_df = filtered_df.copy()
    merged_df.insert(0, 'disease', disease_for_emb)

    # Display head
    print("Merged dataframe (with 'disease' as first column):")
    display(merged_df)
    
    # Save to cache
    print("Saving merged dataframe to cache...")
    with open(merge_cache_file, 'wb') as f:
        pickle.dump(merged_df, f)
# Out:
# Merging embeddings with metadata (this may take a while)...
# Merged dataframe head (with 'disease' as first column):
#                          disease     emb_0     emb_1     emb_2     emb_3  \
# id
# GSM1051881  rheumatoid arthritis -0.001305  0.000200  0.001953 -0.002734
# GSM1051977  rheumatoid arthritis  0.000590 -0.001857 -0.002502  0.002780
# GSM1052156  rheumatoid arthritis  0.000802  0.004568  0.006876  0.001612
# GSM1051741  rheumatoid arthritis -0.003565 -0.002953  0.000190 -0.004830
# GSM1051729  rheumatoid arthritis  0.003396  0.000118 -0.000663  0.006748
#
#                emb_4     emb_5     emb_6     emb_7     emb_8  ...   emb_502  \
# id                                                            ...
# GSM1051881  0.000159  0.001963 -0.000451 -0.005499  0.002583  ...  0.001220
# GSM1051977 -0.001102 -0.001300 -0.001350 -0.001323 -0.004603  ... -0.000943
# GSM1052156 -0.002390  0.007284 -0.002453 -0.001633 -0.000554  ... -0.003316
# GSM1051741  0.000698  0.003887 -0.004089 -0.004348  0.004465  ...  0.001848
# GSM1051729 -0.002380  0.002448 -0.000839 -0.004645 -0.002241  ... -0.001094
#
#              emb_503   emb_504   emb_505   emb_506   emb_507   emb_508  \
# id
# GSM1051881 -0.001565 -0.005460 -0.002010 -0.004003  0.000767  0.000756
# GSM1051977  0.004626 -0.001879 -0.000146  0.002117 -0.001068  0.001165
# GSM1052156  0.002482 -0.001748  0.001319 -0.003379 -0.003346 -0.000742
# GSM1051741 -0.001194  0.002220  0.000575 -0.002808  0.000373 -0.001696
# GSM1051729 -0.001565  0.001197 -0.001617  0.000472  0.005212 -0.000733
#
#              emb_509   emb_510   emb_511
# id
# GSM1051881 -0.003183  0.001178 -0.002373
# GSM1051977 -0.001526  0.000915  0.000664
# GSM1052156  0.000892 -0.001373 -0.003123
# GSM1051741 -0.004429 -0.000311 -0.000372
# GSM1051729 -0.000215  0.001592  0.002087
#
# [5 rows x 513 columns]
# Saving merged dataframe to cache...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import RidgeClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report
from typing import Dict, Any, Tuple
import pickle
import os

# Check if baseline model is already cached
project_root = os.path.abspath(os.path.join(os.getcwd(), '..')) if os.path.basename(os.getcwd()) == 'notebooks' else os.getcwd()
baseline_cache_file = os.path.join(project_root, 'data', 'baseline_model_metrics.pkl')

if os.path.exists(baseline_cache_file):
    print("Loading baseline model and metrics from cache...")
    with open(baseline_cache_file, 'rb') as f:
        baseline_data = pickle.load(f)
    baseline_model = baseline_data['model']
    baseline_metrics = baseline_data['metrics']
    print("Validation accuracy:", baseline_metrics['accuracy'])
    print("Validation macro F1:", baseline_metrics['f1_macro'])
else:
    print("Training baseline Ridge classifier (this may take a while)...")
    
    # Validate prerequisites
    if 'merged_df' not in globals():
        raise RuntimeError("'merged_df' not found. Ensure previous cells were executed.")

    def train_ridge_classifier(
        df: 'pd.DataFrame',
        target_col: str = 'disease',
        test_size: float = 0.2,
        random_state: int = 42,
        stratify: bool = True,
    ) -> Tuple[Pipeline, Dict[str, Any]]:
        """Split, train and evaluate a Ridge classifier on the provided dataframe.

        Returns the fitted pipeline and a metrics dict with accuracy, macro F1, and the full report.
        """
        import pandas as pd

        y_local = df[target_col]
        X_local = df.drop(columns=[target_col])

        has_nan_features = bool(X_local.isna().any().any())
        has_nan_target = bool(y_local.isna().any())
        if has_nan_features or has_nan_target:
            mask_local = (X_local.notna().all(axis=1)) & y_local.notna()
            X_local = X_local.loc[mask_local]
            y_local = y_local.loc[mask_local]

        stratify_vals = y_local if (stratify and y_local.nunique() > 1) else None
        X_tr, X_te, y_tr, y_te = train_test_split(
            X_local, y_local, test_size=test_size, random_state=random_state, stratify=stratify_vals
        )

        model = Pipeline([
            ('scaler', StandardScaler(with_mean=False)),
            ('ridge', RidgeClassifier(random_state=random_state))
        ])
        model.fit(X_tr, y_tr)

        y_hat = model.predict(X_te)
        metrics = {
            'accuracy': accuracy_score(y_te, y_hat),
            'f1_macro': f1_score(y_te, y_hat, average='macro'),
            'report': classification_report(y_te, y_hat, output_dict=False),
            'y_true': y_te,
            'y_pred': y_hat,
        }

        print("Validation accuracy:", metrics['accuracy'])
        print("Validation macro F1:", metrics['f1_macro'])
        print("\nClassification report:\n")
        print(metrics['report'])

        return model, metrics

    # Train baseline classifier on merged_df
    baseline_model, baseline_metrics = train_ridge_classifier(merged_df)
    
    # Save to cache
    print("Saving baseline model and metrics to cache...")
    baseline_data = {'model': baseline_model, 
                     'metrics': baseline_metrics}
    with open(baseline_cache_file, 'wb') as f:
        pickle.dump(baseline_data, f)
# Out:
# Training baseline Ridge classifier (this may take a while)...
# Validation accuracy: 0.857487922705314
# Validation macro F1: 0.649228118044087
#
# Classification report:
#
#                       precision    recall  f1-score   support
#
#               Normal       0.64      0.27      0.38        67
# rheumatoid arthritis       0.87      0.97      0.92       347
#
#             accuracy                           0.86       414
#            macro avg       0.76      0.62      0.65       414
#         weighted avg       0.84      0.86      0.83       414
#
# Saving baseline model and metrics to cache...

# %%
import pandas as pd
from sdv.single_table import GaussianCopulaSynthesizer
from sdv.metadata import Metadata

# Validate prerequisites
if 'merged_df' not in globals():
    raise RuntimeError(
        "'merged_df' not found. Ensure previous cells were executed.")

# Create train/validation split for SDV
from sklearn.model_selection import train_test_split
y_all = merged_df['disease']
X_all = merged_df.drop(columns=['disease'])
if X_all.isna().any().any() or y_all.isna().any():
    m = (~X_all.isna().any(axis=1)) & y_all.notna()
    X_all, y_all = X_all.loc[m], y_all.loc[m]

X_train, X_val, y_train, y_val = train_test_split(
    X_all, 
    y_all,
    test_size=0.2,
    random_state=42,
    stratify=y_all if y_all.nunique() > 1 else None
)

# Build a single-table DataFrame for SDV with target included
train_with_target = X_train.copy()
train_with_target.insert(0, 'disease', y_train)

# Create SDV Metadata inferred from the training data
metadata = Metadata.detect_from_dataframe(train_with_target, 'embeddings_train')

# Fit Gaussian Copula synthesizer with KDE as default distribution
synthesizer = GaussianCopulaSynthesizer(
    metadata,
    default_distribution='gaussian_kde'
)
synthesizer.fit(train_with_target)

# Generate synthetic rows: 2x additional to get 3x total size
num_rows_real = len(train_with_target)
num_rows_synth = 2 * num_rows_real
synthetic_train = synthesizer.sample(num_rows=num_rows_synth)

# Combine real and synthetic
augmented_train = pd.concat(
    [train_with_target, synthetic_train], axis=0, ignore_index=True)

print("Original train shape:", train_with_target.shape)
print("Synthetic rows:", synthetic_train.shape)
print("Augmented train shape:", augmented_train.shape)

# Display head of augmented training data
display(augmented_train)
# Out:
# C:\Users\ferdi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sdv\single_table\base.py:128: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# Original train shape: (1653, 513)
# Synthetic rows: (3306, 513)
# Augmented train shape: (4959, 513)
#                 disease     emb_0     emb_1     emb_2     emb_3     emb_4  \
# 0  rheumatoid arthritis -0.002477  0.003586  0.012243 -0.000533 -0.004430
# 1  rheumatoid arthritis  0.006394 -0.000444 -0.001226  0.006966 -0.002765
# 2  rheumatoid arthritis -0.005281 -0.001189  0.000055 -0.009545  0.001670
# 3  rheumatoid arthritis -0.002604  0.005943 -0.002124 -0.001965 -0.000431
# 4  rheumatoid arthritis  0.003255  0.003624 -0.006537  0.006363 -0.002228
#
#       emb_5     emb_6     emb_7     emb_8  ...   emb_502   emb_503   emb_504  \
# 0  0.007843 -0.006109 -0.003373 -0.001639  ... -0.000257 -0.001067 -0.000298
# 1  0.000425  0.003337  0.001329 -0.006819  ... -0.000235  0.001581  0.002133
# 2  0.001360 -0.003920 -0.009408  0.009124  ... -0.001043  0.000250 -0.002847
# 3  0.003388  0.000245 -0.002233 -0.005134  ... -0.006915  0.002561 -0.000364
# 4 -0.001518  0.003916  0.005647 -0.005919  ... -0.005102  0.008667  0.001729
#
#     emb_505   emb_506   emb_507   emb_508   emb_509   emb_510   emb_511
# 0 -0.003455 -0.005516 -0.005543  0.000220  0.002824 -0.002563  0.000242
# 1 -0.003830  0.000141  0.003038 -0.000518  0.000946  0.001316  0.000408
# 2  0.002873 -0.001487 -0.003244  0.002232 -0.001140 -0.005581 -0.001701
# 3  0.001076  0.000784 -0.005202  0.002143  0.000434  0.001442  0.001583
# 4  0.001987  0.002010  0.000687 -0.001283 -0.003154  0.000097 -0.000038
#
# [5 rows x 513 columns]

# %%
# Train on augmented data using the reusable function
if 'augmented_train' not in globals():
    raise RuntimeError("'augmented_train' not found. Run the augmentation "
    "cell first.")

augmented_model, augmented_metrics = train_ridge_classifier(augmented_train)

print("\nAugmented training performance:")
print("Accuracy:", augmented_metrics['accuracy'])
print("Macro F1:", augmented_metrics['f1_macro'])
# Out:
# Validation accuracy: 0.8336693548387096
# Validation macro F1: 0.579901597184971
#
# Classification report:
#
#                       precision    recall  f1-score   support
#
#               Normal       0.55      0.16      0.25       170
# rheumatoid arthritis       0.85      0.97      0.91       822
#
#             accuracy                           0.83       992
#            macro avg       0.70      0.57      0.58       992
#         weighted avg       0.80      0.83      0.79       992
#
#
# Augmented training performance:
# Accuracy: 0.8336693548387096
# Macro F1: 0.579901597184971

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Compare baseline vs augmented performance
if 'baseline_metrics' not in globals() or 'augmented_metrics' not in globals():
    raise RuntimeError("Missing metrics. Ensure both baseline and augmented models were trained.")

metrics_to_plot = ['accuracy', 'f1_macro']
values = pd.DataFrame({
    'baseline': [baseline_metrics[m] for m in metrics_to_plot],
    'augmented': [augmented_metrics[m] for m in metrics_to_plot],
}, index=metrics_to_plot)

ax = values.plot(kind='bar', figsize=(6, 4), rot=0, grid=True, ylim=(0, 1))
ax.set_title('Validation Performance: Baseline vs Augmented')
ax.set_ylabel('Score')
ax.legend(title='Model')
plt.tight_layout()
plt.show()

# %%
# Optimize synthetic data quality by selecting best synthesizer
import pandas as pd
import numpy as np
from sdv.single_table import GaussianCopulaSynthesizer, CTGANSynthesizer, TVAESynthesizer
from sdv.metadata import Metadata
from sdv.evaluation.single_table import evaluate_quality
from sklearn.model_selection import train_test_split
from typing import Dict, Any, Tuple, Union

def optimize_synthesizer(
    synthesizer_type: str,
    train_data: pd.DataFrame,
    target_col: str = 'disease',
    num_candidates: int = 5,
    sample_size: int = 2000
) -> Tuple[Any, Dict[str, Any], pd.DataFrame]:
    """
    Optimize synthesizer by testing different configurations and selecting the best.
    
    Args:
        synthesizer_type: Type of synthesizer ('gaussian_copula', 'ctgan', 'tvae')
        train_data: Training data with target column
        target_col: Name of target column
        num_candidates: Number of configurations to test
        sample_size: Size of synthetic samples for evaluation
        
    Returns:
        Tuple of (best_synthesizer, best_metrics, augmented_dataframe)
    """
    
    # Create metadata
    metadata = Metadata.detect_from_dataframe(train_data, 'embeddings_train')
    
    if synthesizer_type == 'gaussian_copula':
        # Test different default distributions
        candidates = ['gaussian_kde', 'norm', 'truncnorm', 'gamma', 'beta'][:num_candidates]
        synthesizers = {}
        
        for dist in candidates:
            synth = GaussianCopulaSynthesizer(metadata, default_distribution=dist)
            synth.fit(train_data)
            synthesizers[dist] = synth
            
    elif synthesizer_type == 'ctgan':
        # Test different CTGAN configurations
        candidates = ['default', 'epochs_100', 'epochs_200', 'batch_500', 'batch_1000'][:num_candidates]
        synthesizers = {}
        
        for config in candidates:
            synth = CTGANSynthesizer(metadata)  # Initialize with default
            if config == 'epochs_100':
                synth = CTGANSynthesizer(metadata, epochs=100)
            elif config == 'epochs_200':
                synth = CTGANSynthesizer(metadata, epochs=200)
            elif config == 'batch_500':
                synth = CTGANSynthesizer(metadata, batch_size=500)
            elif config == 'batch_1000':
                synth = CTGANSynthesizer(metadata, batch_size=1000)
            
            synth.fit(train_data)
            synthesizers[config] = synth
            
    elif synthesizer_type == 'tvae':
        # Test different TVAE configurations
        candidates = ['default', 'epochs_100', 'epochs_200', 'batch_500', 'batch_1000'][:num_candidates]
        synthesizers = {}
        
        for config in candidates:
            synth = TVAESynthesizer(metadata)  # Initialize with default
            if config == 'epochs_100':
                synth = TVAESynthesizer(metadata, epochs=100)
            elif config == 'epochs_200':
                synth = TVAESynthesizer(metadata, epochs=200)
            elif config == 'batch_500':
                synth = TVAESynthesizer(metadata, batch_size=500)
            elif config == 'batch_1000':
                synth = TVAESynthesizer(metadata, batch_size=1000)
            
            synth.fit(train_data)
            synthesizers[config] = synth
    else:
        raise ValueError(f"Unknown synthesizer type: {synthesizer_type}")
    
    # Evaluate each synthesizer
    quality_scores = {}
    for config, synth in synthesizers.items():
        try:
            synth_samples = synth.sample(
                num_rows=int(min(sample_size, len(train_data))))
            report = evaluate_quality(
                real_data=train_data, 
                synthetic_data=synth_samples, 
                metadata=metadata
            )
            raw_score = report.get_score()
            score = float(raw_score) if raw_score is not None else 0.0
            quality_scores[config] = score
            print(f"{synthesizer_type} - {config}: quality score = {score:.4f}")
        except Exception as e:
            print(f"{synthesizer_type} - {config}: failed with error {e}")
            quality_scores[config] = 0.0
    
    # Select best configuration
    best_config = sorted(quality_scores.items(), key=lambda kv: kv[1], reverse=True)[0][0]
    best_synth = synthesizers[best_config]
    print(f"Best {synthesizer_type} configuration: {best_config}")
    
    # Generate augmented data with best synthesizer
    num_rows_real = len(train_data)
    synthetic_best = best_synth.sample(num_rows=2 * num_rows_real)
    augmented_data = pd.concat(
        [train_data, synthetic_best], 
        axis=0, 
        ignore_index=True
    )
    
    # Train classifier and get metrics
    model, metrics = train_ridge_classifier(augmented_data)
    
    return best_synth, metrics, augmented_data

# Load synthesizer results from files if they don't exist in memory
import pickle
import os

def load_synthesizer_data():
    """Load synthesizer data from pickle files if variables don't exist in globals."""
    data_dir = 'data'
    variables_to_load = [
        'gc_synth', 'gc_metrics', 'gc_augmented',
        'ctgan_synth', 'ctgan_metrics', 'ctgan_augmented', 
        'tvae_synth', 'tvae_metrics', 'tvae_augmented'
    ]
    
    loaded_count = 0
    for var_name in variables_to_load:
        if var_name not in globals():
            filepath = os.path.join(data_dir, f'{var_name}.pkl')
            if os.path.exists(filepath):
                try:
                    with open(filepath, 'rb') as f:
                        globals()[var_name] = pickle.load(f)
                    print(f"Loaded {var_name} from {filepath}")
                    loaded_count += 1
                except Exception as e:
                    print(f"Failed to load {var_name}: {e}")
    
    if loaded_count > 0:
        print(f"\nLoaded {loaded_count} variables from files")
    else:
        print("No variables loaded from files (either already in memory or files don't exist)")

# Load data if available
load_synthesizer_data()

# Prepare training data
if 'merged_df' not in globals():
    raise RuntimeError("'merged_df' not found. Ensure earlier cells ran.")

y_all = merged_df['disease']
X_all = merged_df.drop(columns=['disease'])
if X_all.isna().any().any() or y_all.isna().any():
    m = (~X_all.isna().any(axis=1)) & y_all.notna()
    X_all, y_all = X_all.loc[m], y_all.loc[m]

X_train_local, X_val_local, y_train_local, y_val_local = train_test_split(
    X_all,
    y_all,
    test_size=0.2,
    random_state=42,
    stratify=y_all if y_all.nunique() > 1 else None
)

train_with_target = X_train_local.copy()
train_with_target.insert(0, 'disease', y_train_local)

# Test GaussianCopula (original optimization)
print("=== Testing GaussianCopula ===")
if 'gc_synth' not in globals():
    gc_synth, gc_metrics, gc_augmented = (
        optimize_synthesizer(
            'gaussian_copula', pd.DataFrame(train_with_target)
        )
    )
else:
    print("GaussianCopula results already loaded from previous run")

# Test CTGAN
print("\n=== Testing CTGAN ===")
if 'ctgan_synth' not in globals():
    ctgan_synth, ctgan_metrics, ctgan_augmented = optimize_synthesizer('ctgan', pd.DataFrame(train_with_target))
else:
    print("CTGAN results already loaded from previous run")

# Test TVAE
print("\n=== Testing TVAE ===")
if 'tvae_synth' not in globals():
    tvae_synth, tvae_metrics, tvae_augmented = optimize_synthesizer('tvae', pd.DataFrame(train_with_target))
else:
    print("TVAE results already loaded from previous run")
# Out:
# No variables loaded from files (either already in memory or files don't exist)
# === Testing GaussianCopula ===
# C:\Users\ferdi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sdv\single_table\base.py:128: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:01<00:00, 335.80it/s]|
# Column Shapes Score: 97.25%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [12:58<00:00, 168.72it/s]|
# Column Pair Trends Score: 98.99%
#
# Overall Score (Average): 98.12%
#
# gaussian_copula - gaussian_kde: quality score = 0.9812
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:01<00:00, 388.14it/s]|
# Column Shapes Score: 95.75%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [13:01<00:00, 167.95it/s]|
# Column Pair Trends Score: 99.05%
#
# Overall Score (Average): 97.4%
#
# gaussian_copula - norm: quality score = 0.9740
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:01<00:00, 348.27it/s]|
# Column Shapes Score: 71.25%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [13:03<00:00, 167.71it/s]|
# Column Pair Trends Score: 98.56%
#
# Overall Score (Average): 84.9%
#
# gaussian_copula - truncnorm: quality score = 0.8490
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:01<00:00, 452.19it/s]|
# Column Shapes Score: 89.91%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [13:01<00:00, 168.05it/s]|
# Column Pair Trends Score: 97.97%
#
# Overall Score (Average): 93.94%
#
# gaussian_copula - gamma: quality score = 0.9394
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:01<00:00, 456.02it/s]|
# Column Shapes Score: 81.46%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [11:40<00:00, 187.50it/s]|
# Column Pair Trends Score: 98.28%
#
# Overall Score (Average): 89.87%
#
# gaussian_copula - beta: quality score = 0.8987
# Best gaussian_copula configuration: gaussian_kde
# Validation accuracy: 0.8346774193548387
# Validation macro F1: 0.5558225124772025
#
# Classification report:
#
#                       precision    recall  f1-score   support
#
#               Normal       0.48      0.13      0.20       162
# rheumatoid arthritis       0.85      0.97      0.91       830
#
#             accuracy                           0.83       992
#            macro avg       0.66      0.55      0.56       992
#         weighted avg       0.79      0.83      0.79       992
#
#
# === Testing CTGAN ===
# C:\Users\ferdi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sdv\single_table\base.py:128: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# PerformanceAlert: Using the CTGANSynthesizer on this data is not recommended. To model this data, CTGAN will generate a large number of columns.
#
# Original Column Name   Est # of Columns (CTGAN)
# disease                2
# emb_0                  11
# emb_1                  11
# emb_2                  11
# emb_3                  11
# emb_4                  11
# emb_5                  11
# emb_6                  11
# emb_7                  11
# emb_8                  11
# emb_9                  11
# emb_10                 11
# emb_11                 11
# emb_12                 11
# emb_13                 11
# emb_14                 11
# emb_15                 11
# emb_16                 11
# emb_17                 11
# emb_18                 11
# emb_19                 11
# emb_20                 11
# emb_21                 11
# emb_22                 11
# emb_23                 11
# emb_24                 11
# emb_25                 11
# emb_26                 11
# emb_27                 11
# emb_28                 11
# emb_29                 11
# emb_30                 11
# emb_31                 11
# emb_32                 11
# emb_33                 11
# emb_34                 11
# emb_35                 11
# emb_36                 11
# emb_37                 11
# emb_38                 11
# emb_39                 11
# emb_40                 11
# emb_41                 11
# emb_42                 11
# emb_43                 11
# emb_44                 11
# emb_45                 11
# emb_46                 11
# emb_47                 11
# emb_48                 11
# emb_49                 11
# emb_50                 11
# emb_51                 11
# emb_52                 11
# emb_53                 11
# emb_54                 11
# emb_55                 11
# emb_56                 11
# emb_57                 11
# emb_58                 11
# emb_59                 11
# emb_60                 11
# emb_61                 11
# emb_62                 11
# emb_63                 11
# emb_64                 11
# emb_65                 11
# emb_66                 11
# emb_67                 11
# emb_68                 11
# emb_69                 11
# emb_70                 11
# emb_71                 11
# emb_72                 11
# emb_73                 11
# emb_74                 11
# emb_75                 11
# emb_76                 11
# emb_77                 11
# emb_78                 11
# emb_79                 11
# emb_80                 11
# emb_81                 11
# emb_82                 11
# emb_83                 11
# emb_84                 11
# emb_85                 11
# emb_86                 11
# emb_87                 11
# emb_88                 11
# emb_89                 11
# emb_90                 11
# emb_91                 11
# emb_92                 11
# emb_93                 11
# emb_94                 11
# emb_95                 11
# emb_96                 11
# emb_97                 11
# emb_98                 11
# emb_99                 11
# emb_100                11
# emb_101                11
# emb_102                11
# emb_103                11
# emb_104                11
# emb_105                11
# emb_106                11
# emb_107                11
# emb_108                11
# emb_109                11
# emb_110                11
# emb_111                11
# emb_112                11
# emb_113                11
# emb_114                11
# emb_115                11
# emb_116                11
# emb_117                11
# emb_118                11
# emb_119                11
# emb_120                11
# emb_121                11
# emb_122                11
# emb_123                11
# emb_124                11
# emb_125                11
# emb_126                11
# emb_127                11
# emb_128                11
# emb_129                11
# emb_130                11
# emb_131                11
# emb_132                11
# emb_133                11
# emb_134                11
# emb_135                11
# emb_136                11
# emb_137                11
# emb_138                11
# emb_139                11
# emb_140                11
# emb_141                11
# emb_142                11
# emb_143                11
# emb_144                11
# emb_145                11
# emb_146                11
# emb_147                11
# emb_148                11
# emb_149                11
# emb_150                11
# emb_151                11
# emb_152                11
# emb_153                11
# emb_154                11
# emb_155                11
# emb_156                11
# emb_157                11
# emb_158                11
# emb_159                11
# emb_160                11
# emb_161                11
# emb_162                11
# emb_163                11
# emb_164                11
# emb_165                11
# emb_166                11
# emb_167                11
# emb_168                11
# emb_169                11
# emb_170                11
# emb_171                11
# emb_172                11
# emb_173                11
# emb_174                11
# emb_175                11
# emb_176                11
# emb_177                11
# emb_178                11
# emb_179                11
# emb_180                11
# emb_181                11
# emb_182                11
# emb_183                11
# emb_184                11
# emb_185                11
# emb_186                11
# emb_187                11
# emb_188                11
# emb_189                11
# emb_190                11
# emb_191                11
# emb_192                11
# emb_193                11
# emb_194                11
# emb_195                11
# emb_196                11
# emb_197                11
# emb_198                11
# emb_199                11
# emb_200                11
# emb_201                11
# emb_202                11
# emb_203                11
# emb_204                11
# emb_205                11
# emb_206                11
# emb_207                11
# emb_208                11
# emb_209                11
# emb_210                11
# emb_211                11
# emb_212                11
# emb_213                11
# emb_214                11
# emb_215                11
# emb_216                11
# emb_217                11
# emb_218                11
# emb_219                11
# emb_220                11
# emb_221                11
# emb_222                11
# emb_223                11
# emb_224                11
# emb_225                11
# emb_226                11
# emb_227                11
# emb_228                11
# emb_229                11
# emb_230                11
# emb_231                11
# emb_232                11
# emb_233                11
# emb_234                11
# emb_235                11
# emb_236                11
# emb_237                11
# emb_238                11
# emb_239                11
# emb_240                11
# emb_241                11
# emb_242                11
# emb_243                11
# emb_244                11
# emb_245                11
# emb_246                11
# emb_247                11
# emb_248                11
# emb_249                11
# emb_250                11
# emb_251                11
# emb_252                11
# emb_253                11
# emb_254                11
# emb_255                11
# emb_256                11
# emb_257                11
# emb_258                11
# emb_259                11
# emb_260                11
# emb_261                11
# emb_262                11
# emb_263                11
# emb_264                11
# emb_265                11
# emb_266                11
# emb_267                11
# emb_268                11
# emb_269                11
# emb_270                11
# emb_271                11
# emb_272                11
# emb_273                11
# emb_274                11
# emb_275                11
# emb_276                11
# emb_277                11
# emb_278                11
# emb_279                11
# emb_280                11
# emb_281                11
# emb_282                11
# emb_283                11
# emb_284                11
# emb_285                11
# emb_286                11
# emb_287                11
# emb_288                11
# emb_289                11
# emb_290                11
# emb_291                11
# emb_292                11
# emb_293                11
# emb_294                11
# emb_295                11
# emb_296                11
# emb_297                11
# emb_298                11
# emb_299                11
# emb_300                11
# emb_301                11
# emb_302                11
# emb_303                11
# emb_304                11
# emb_305                11
# emb_306                11
# emb_307                11
# emb_308                11
# emb_309                11
# emb_310                11
# emb_311                11
# emb_312                11
# emb_313                11
# emb_314                11
# emb_315                11
# emb_316                11
# emb_317                11
# emb_318                11
# emb_319                11
# emb_320                11
# emb_321                11
# emb_322                11
# emb_323                11
# emb_324                11
# emb_325                11
# emb_326                11
# emb_327                11
# emb_328                11
# emb_329                11
# emb_330                11
# emb_331                11
# emb_332                11
# emb_333                11
# emb_334                11
# emb_335                11
# emb_336                11
# emb_337                11
# emb_338                11
# emb_339                11
# emb_340                11
# emb_341                11
# emb_342                11
# emb_343                11
# emb_344                11
# emb_345                11
# emb_346                11
# emb_347                11
# emb_348                11
# emb_349                11
# emb_350                11
# emb_351                11
# emb_352                11
# emb_353                11
# emb_354                11
# emb_355                11
# emb_356                11
# emb_357                11
# emb_358                11
# emb_359                11
# emb_360                11
# emb_361                11
# emb_362                11
# emb_363                11
# emb_364                11
# emb_365                11
# emb_366                11
# emb_367                11
# emb_368                11
# emb_369                11
# emb_370                11
# emb_371                11
# emb_372                11
# emb_373                11
# emb_374                11
# emb_375                11
# emb_376                11
# emb_377                11
# emb_378                11
# emb_379                11
# emb_380                11
# emb_381                11
# emb_382                11
# emb_383                11
# emb_384                11
# emb_385                11
# emb_386                11
# emb_387                11
# emb_388                11
# emb_389                11
# emb_390                11
# emb_391                11
# emb_392                11
# emb_393                11
# emb_394                11
# emb_395                11
# emb_396                11
# emb_397                11
# emb_398                11
# emb_399                11
# emb_400                11
# emb_401                11
# emb_402                11
# emb_403                11
# emb_404                11
# emb_405                11
# emb_406                11
# emb_407                11
# emb_408                11
# emb_409                11
# emb_410                11
# emb_411                11
# emb_412                11
# emb_413                11
# emb_414                11
# emb_415                11
# emb_416                11
# emb_417                11
# emb_418                11
# emb_419                11
# emb_420                11
# emb_421                11
# emb_422                11
# emb_423                11
# emb_424                11
# emb_425                11
# emb_426                11
# emb_427                11
# emb_428                11
# emb_429                11
# emb_430                11
# emb_431                11
# emb_432                11
# emb_433                11
# emb_434                11
# emb_435                11
# emb_436                11
# emb_437                11
# emb_438                11
# emb_439                11
# emb_440                11
# emb_441                11
# emb_442                11
# emb_443                11
# emb_444                11
# emb_445                11
# emb_446                11
# emb_447                11
# emb_448                11
# emb_449                11
# emb_450                11
# emb_451                11
# emb_452                11
# emb_453                11
# emb_454                11
# emb_455                11
# emb_456                11
# emb_457                11
# emb_458                11
# emb_459                11
# emb_460                11
# emb_461                11
# emb_462                11
# emb_463                11
# emb_464                11
# emb_465                11
# emb_466                11
# emb_467                11
# emb_468                11
# emb_469                11
# emb_470                11
# emb_471                11
# emb_472                11
# emb_473                11
# emb_474                11
# emb_475                11
# emb_476                11
# emb_477                11
# emb_478                11
# emb_479                11
# emb_480                11
# emb_481                11
# emb_482                11
# emb_483                11
# emb_484                11
# emb_485                11
# emb_486                11
# emb_487                11
# emb_488                11
# emb_489                11
# emb_490                11
# emb_491                11
# emb_492                11
# emb_493                11
# emb_494                11
# emb_495                11
# emb_496                11
# emb_497                11
# emb_498                11
# emb_499                11
# emb_500                11
# emb_501                11
# emb_502                11
# emb_503                11
# emb_504                11
# emb_505                11
# emb_506                11
# emb_507                11
# emb_508                11
# emb_509                11
# emb_510                11
# emb_511                11
#
# We recommend preprocessing discrete columns that can have many values, using 'update_transformers'. Or you may drop columns that are not necessary to model. (Exit this script using ctrl-C)
# PerformanceAlert: Using the CTGANSynthesizer on this data is not recommended. To model this data, CTGAN will generate a large number of columns.
#
# Original Column Name   Est # of Columns (CTGAN)
# disease                2
# emb_0                  11
# emb_1                  11
# emb_2                  11
# emb_3                  11
# emb_4                  11
# emb_5                  11
# emb_6                  11
# emb_7                  11
# emb_8                  11
# emb_9                  11
# emb_10                 11
# emb_11                 11
# emb_12                 11
# emb_13                 11
# emb_14                 11
# emb_15                 11
# emb_16                 11
# emb_17                 11
# emb_18                 11
# emb_19                 11
# emb_20                 11
# emb_21                 11
# emb_22                 11
# emb_23                 11
# emb_24                 11
# emb_25                 11
# emb_26                 11
# emb_27                 11
# emb_28                 11
# emb_29                 11
# emb_30                 11
# emb_31                 11
# emb_32                 11
# emb_33                 11
# emb_34                 11
# emb_35                 11
# emb_36                 11
# emb_37                 11
# emb_38                 11
# emb_39                 11
# emb_40                 11
# emb_41                 11
# emb_42                 11
# emb_43                 11
# emb_44                 11
# emb_45                 11
# emb_46                 11
# emb_47                 11
# emb_48                 11
# emb_49                 11
# emb_50                 11
# emb_51                 11
# emb_52                 11
# emb_53                 11
# emb_54                 11
# emb_55                 11
# emb_56                 11
# emb_57                 11
# emb_58                 11
# emb_59                 11
# emb_60                 11
# emb_61                 11
# emb_62                 11
# emb_63                 11
# emb_64                 11
# emb_65                 11
# emb_66                 11
# emb_67                 11
# emb_68                 11
# emb_69                 11
# emb_70                 11
# emb_71                 11
# emb_72                 11
# emb_73                 11
# emb_74                 11
# emb_75                 11
# emb_76                 11
# emb_77                 11
# emb_78                 11
# emb_79                 11
# emb_80                 11
# emb_81                 11
# emb_82                 11
# emb_83                 11
# emb_84                 11
# emb_85                 11
# emb_86                 11
# emb_87                 11
# emb_88                 11
# emb_89                 11
# emb_90                 11
# emb_91                 11
# emb_92                 11
# emb_93                 11
# emb_94                 11
# emb_95                 11
# emb_96                 11
# emb_97                 11
# emb_98                 11
# emb_99                 11
# emb_100                11
# emb_101                11
# emb_102                11
# emb_103                11
# emb_104                11
# emb_105                11
# emb_106                11
# emb_107                11
# emb_108                11
# emb_109                11
# emb_110                11
# emb_111                11
# emb_112                11
# emb_113                11
# emb_114                11
# emb_115                11
# emb_116                11
# emb_117                11
# emb_118                11
# emb_119                11
# emb_120                11
# emb_121                11
# emb_122                11
# emb_123                11
# emb_124                11
# emb_125                11
# emb_126                11
# emb_127                11
# emb_128                11
# emb_129                11
# emb_130                11
# emb_131                11
# emb_132                11
# emb_133                11
# emb_134                11
# emb_135                11
# emb_136                11
# emb_137                11
# emb_138                11
# emb_139                11
# emb_140                11
# emb_141                11
# emb_142                11
# emb_143                11
# emb_144                11
# emb_145                11
# emb_146                11
# emb_147                11
# emb_148                11
# emb_149                11
# emb_150                11
# emb_151                11
# emb_152                11
# emb_153                11
# emb_154                11
# emb_155                11
# emb_156                11
# emb_157                11
# emb_158                11
# emb_159                11
# emb_160                11
# emb_161                11
# emb_162                11
# emb_163                11
# emb_164                11
# emb_165                11
# emb_166                11
# emb_167                11
# emb_168                11
# emb_169                11
# emb_170                11
# emb_171                11
# emb_172                11
# emb_173                11
# emb_174                11
# emb_175                11
# emb_176                11
# emb_177                11
# emb_178                11
# emb_179                11
# emb_180                11
# emb_181                11
# emb_182                11
# emb_183                11
# emb_184                11
# emb_185                11
# emb_186                11
# emb_187                11
# emb_188                11
# emb_189                11
# emb_190                11
# emb_191                11
# emb_192                11
# emb_193                11
# emb_194                11
# emb_195                11
# emb_196                11
# emb_197                11
# emb_198                11
# emb_199                11
# emb_200                11
# emb_201                11
# emb_202                11
# emb_203                11
# emb_204                11
# emb_205                11
# emb_206                11
# emb_207                11
# emb_208                11
# emb_209                11
# emb_210                11
# emb_211                11
# emb_212                11
# emb_213                11
# emb_214                11
# emb_215                11
# emb_216                11
# emb_217                11
# emb_218                11
# emb_219                11
# emb_220                11
# emb_221                11
# emb_222                11
# emb_223                11
# emb_224                11
# emb_225                11
# emb_226                11
# emb_227                11
# emb_228                11
# emb_229                11
# emb_230                11
# emb_231                11
# emb_232                11
# emb_233                11
# emb_234                11
# emb_235                11
# emb_236                11
# emb_237                11
# emb_238                11
# emb_239                11
# emb_240                11
# emb_241                11
# emb_242                11
# emb_243                11
# emb_244                11
# emb_245                11
# emb_246                11
# emb_247                11
# emb_248                11
# emb_249                11
# emb_250                11
# emb_251                11
# emb_252                11
# emb_253                11
# emb_254                11
# emb_255                11
# emb_256                11
# emb_257                11
# emb_258                11
# emb_259                11
# emb_260                11
# emb_261                11
# emb_262                11
# emb_263                11
# emb_264                11
# emb_265                11
# emb_266                11
# emb_267                11
# emb_268                11
# emb_269                11
# emb_270                11
# emb_271                11
# emb_272                11
# emb_273                11
# emb_274                11
# emb_275                11
# emb_276                11
# emb_277                11
# emb_278                11
# emb_279                11
# emb_280                11
# emb_281                11
# emb_282                11
# emb_283                11
# emb_284                11
# emb_285                11
# emb_286                11
# emb_287                11
# emb_288                11
# emb_289                11
# emb_290                11
# emb_291                11
# emb_292                11
# emb_293                11
# emb_294                11
# emb_295                11
# emb_296                11
# emb_297                11
# emb_298                11
# emb_299                11
# emb_300                11
# emb_301                11
# emb_302                11
# emb_303                11
# emb_304                11
# emb_305                11
# emb_306                11
# emb_307                11
# emb_308                11
# emb_309                11
# emb_310                11
# emb_311                11
# emb_312                11
# emb_313                11
# emb_314                11
# emb_315                11
# emb_316                11
# emb_317                11
# emb_318                11
# emb_319                11
# emb_320                11
# emb_321                11
# emb_322                11
# emb_323                11
# emb_324                11
# emb_325                11
# emb_326                11
# emb_327                11
# emb_328                11
# emb_329                11
# emb_330                11
# emb_331                11
# emb_332                11
# emb_333                11
# emb_334                11
# emb_335                11
# emb_336                11
# emb_337                11
# emb_338                11
# emb_339                11
# emb_340                11
# emb_341                11
# emb_342                11
# emb_343                11
# emb_344                11
# emb_345                11
# emb_346                11
# emb_347                11
# emb_348                11
# emb_349                11
# emb_350                11
# emb_351                11
# emb_352                11
# emb_353                11
# emb_354                11
# emb_355                11
# emb_356                11
# emb_357                11
# emb_358                11
# emb_359                11
# emb_360                11
# emb_361                11
# emb_362                11
# emb_363                11
# emb_364                11
# emb_365                11
# emb_366                11
# emb_367                11
# emb_368                11
# emb_369                11
# emb_370                11
# emb_371                11
# emb_372                11
# emb_373                11
# emb_374                11
# emb_375                11
# emb_376                11
# emb_377                11
# emb_378                11
# emb_379                11
# emb_380                11
# emb_381                11
# emb_382                11
# emb_383                11
# emb_384                11
# emb_385                11
# emb_386                11
# emb_387                11
# emb_388                11
# emb_389                11
# emb_390                11
# emb_391                11
# emb_392                11
# emb_393                11
# emb_394                11
# emb_395                11
# emb_396                11
# emb_397                11
# emb_398                11
# emb_399                11
# emb_400                11
# emb_401                11
# emb_402                11
# emb_403                11
# emb_404                11
# emb_405                11
# emb_406                11
# emb_407                11
# emb_408                11
# emb_409                11
# emb_410                11
# emb_411                11
# emb_412                11
# emb_413                11
# emb_414                11
# emb_415                11
# emb_416                11
# emb_417                11
# emb_418                11
# emb_419                11
# emb_420                11
# emb_421                11
# emb_422                11
# emb_423                11
# emb_424                11
# emb_425                11
# emb_426                11
# emb_427                11
# emb_428                11
# emb_429                11
# emb_430                11
# emb_431                11
# emb_432                11
# emb_433                11
# emb_434                11
# emb_435                11
# emb_436                11
# emb_437                11
# emb_438                11
# emb_439                11
# emb_440                11
# emb_441                11
# emb_442                11
# emb_443                11
# emb_444                11
# emb_445                11
# emb_446                11
# emb_447                11
# emb_448                11
# emb_449                11
# emb_450                11
# emb_451                11
# emb_452                11
# emb_453                11
# emb_454                11
# emb_455                11
# emb_456                11
# emb_457                11
# emb_458                11
# emb_459                11
# emb_460                11
# emb_461                11
# emb_462                11
# emb_463                11
# emb_464                11
# emb_465                11
# emb_466                11
# emb_467                11
# emb_468                11
# emb_469                11
# emb_470                11
# emb_471                11
# emb_472                11
# emb_473                11
# emb_474                11
# emb_475                11
# emb_476                11
# emb_477                11
# emb_478                11
# emb_479                11
# emb_480                11
# emb_481                11
# emb_482                11
# emb_483                11
# emb_484                11
# emb_485                11
# emb_486                11
# emb_487                11
# emb_488                11
# emb_489                11
# emb_490                11
# emb_491                11
# emb_492                11
# emb_493                11
# emb_494                11
# emb_495                11
# emb_496                11
# emb_497                11
# emb_498                11
# emb_499                11
# emb_500                11
# emb_501                11
# emb_502                11
# emb_503                11
# emb_504                11
# emb_505                11
# emb_506                11
# emb_507                11
# emb_508                11
# emb_509                11
# emb_510                11
# emb_511                11
#
# We recommend preprocessing discrete columns that can have many values, using 'update_transformers'. Or you may drop columns that are not necessary to model. (Exit this script using ctrl-C)
# PerformanceAlert: Using the CTGANSynthesizer on this data is not recommended. To model this data, CTGAN will generate a large number of columns.
#
# Original Column Name   Est # of Columns (CTGAN)
# disease                2
# emb_0                  11
# emb_1                  11
# emb_2                  11
# emb_3                  11
# emb_4                  11
# emb_5                  11
# emb_6                  11
# emb_7                  11
# emb_8                  11
# emb_9                  11
# emb_10                 11
# emb_11                 11
# emb_12                 11
# emb_13                 11
# emb_14                 11
# emb_15                 11
# emb_16                 11
# emb_17                 11
# emb_18                 11
# emb_19                 11
# emb_20                 11
# emb_21                 11
# emb_22                 11
# emb_23                 11
# emb_24                 11
# emb_25                 11
# emb_26                 11
# emb_27                 11
# emb_28                 11
# emb_29                 11
# emb_30                 11
# emb_31                 11
# emb_32                 11
# emb_33                 11
# emb_34                 11
# emb_35                 11
# emb_36                 11
# emb_37                 11
# emb_38                 11
# emb_39                 11
# emb_40                 11
# emb_41                 11
# emb_42                 11
# emb_43                 11
# emb_44                 11
# emb_45                 11
# emb_46                 11
# emb_47                 11
# emb_48                 11
# emb_49                 11
# emb_50                 11
# emb_51                 11
# emb_52                 11
# emb_53                 11
# emb_54                 11
# emb_55                 11
# emb_56                 11
# emb_57                 11
# emb_58                 11
# emb_59                 11
# emb_60                 11
# emb_61                 11
# emb_62                 11
# emb_63                 11
# emb_64                 11
# emb_65                 11
# emb_66                 11
# emb_67                 11
# emb_68                 11
# emb_69                 11
# emb_70                 11
# emb_71                 11
# emb_72                 11
# emb_73                 11
# emb_74                 11
# emb_75                 11
# emb_76                 11
# emb_77                 11
# emb_78                 11
# emb_79                 11
# emb_80                 11
# emb_81                 11
# emb_82                 11
# emb_83                 11
# emb_84                 11
# emb_85                 11
# emb_86                 11
# emb_87                 11
# emb_88                 11
# emb_89                 11
# emb_90                 11
# emb_91                 11
# emb_92                 11
# emb_93                 11
# emb_94                 11
# emb_95                 11
# emb_96                 11
# emb_97                 11
# emb_98                 11
# emb_99                 11
# emb_100                11
# emb_101                11
# emb_102                11
# emb_103                11
# emb_104                11
# emb_105                11
# emb_106                11
# emb_107                11
# emb_108                11
# emb_109                11
# emb_110                11
# emb_111                11
# emb_112                11
# emb_113                11
# emb_114                11
# emb_115                11
# emb_116                11
# emb_117                11
# emb_118                11
# emb_119                11
# emb_120                11
# emb_121                11
# emb_122                11
# emb_123                11
# emb_124                11
# emb_125                11
# emb_126                11
# emb_127                11
# emb_128                11
# emb_129                11
# emb_130                11
# emb_131                11
# emb_132                11
# emb_133                11
# emb_134                11
# emb_135                11
# emb_136                11
# emb_137                11
# emb_138                11
# emb_139                11
# emb_140                11
# emb_141                11
# emb_142                11
# emb_143                11
# emb_144                11
# emb_145                11
# emb_146                11
# emb_147                11
# emb_148                11
# emb_149                11
# emb_150                11
# emb_151                11
# emb_152                11
# emb_153                11
# emb_154                11
# emb_155                11
# emb_156                11
# emb_157                11
# emb_158                11
# emb_159                11
# emb_160                11
# emb_161                11
# emb_162                11
# emb_163                11
# emb_164                11
# emb_165                11
# emb_166                11
# emb_167                11
# emb_168                11
# emb_169                11
# emb_170                11
# emb_171                11
# emb_172                11
# emb_173                11
# emb_174                11
# emb_175                11
# emb_176                11
# emb_177                11
# emb_178                11
# emb_179                11
# emb_180                11
# emb_181                11
# emb_182                11
# emb_183                11
# emb_184                11
# emb_185                11
# emb_186                11
# emb_187                11
# emb_188                11
# emb_189                11
# emb_190                11
# emb_191                11
# emb_192                11
# emb_193                11
# emb_194                11
# emb_195                11
# emb_196                11
# emb_197                11
# emb_198                11
# emb_199                11
# emb_200                11
# emb_201                11
# emb_202                11
# emb_203                11
# emb_204                11
# emb_205                11
# emb_206                11
# emb_207                11
# emb_208                11
# emb_209                11
# emb_210                11
# emb_211                11
# emb_212                11
# emb_213                11
# emb_214                11
# emb_215                11
# emb_216                11
# emb_217                11
# emb_218                11
# emb_219                11
# emb_220                11
# emb_221                11
# emb_222                11
# emb_223                11
# emb_224                11
# emb_225                11
# emb_226                11
# emb_227                11
# emb_228                11
# emb_229                11
# emb_230                11
# emb_231                11
# emb_232                11
# emb_233                11
# emb_234                11
# emb_235                11
# emb_236                11
# emb_237                11
# emb_238                11
# emb_239                11
# emb_240                11
# emb_241                11
# emb_242                11
# emb_243                11
# emb_244                11
# emb_245                11
# emb_246                11
# emb_247                11
# emb_248                11
# emb_249                11
# emb_250                11
# emb_251                11
# emb_252                11
# emb_253                11
# emb_254                11
# emb_255                11
# emb_256                11
# emb_257                11
# emb_258                11
# emb_259                11
# emb_260                11
# emb_261                11
# emb_262                11
# emb_263                11
# emb_264                11
# emb_265                11
# emb_266                11
# emb_267                11
# emb_268                11
# emb_269                11
# emb_270                11
# emb_271                11
# emb_272                11
# emb_273                11
# emb_274                11
# emb_275                11
# emb_276                11
# emb_277                11
# emb_278                11
# emb_279                11
# emb_280                11
# emb_281                11
# emb_282                11
# emb_283                11
# emb_284                11
# emb_285                11
# emb_286                11
# emb_287                11
# emb_288                11
# emb_289                11
# emb_290                11
# emb_291                11
# emb_292                11
# emb_293                11
# emb_294                11
# emb_295                11
# emb_296                11
# emb_297                11
# emb_298                11
# emb_299                11
# emb_300                11
# emb_301                11
# emb_302                11
# emb_303                11
# emb_304                11
# emb_305                11
# emb_306                11
# emb_307                11
# emb_308                11
# emb_309                11
# emb_310                11
# emb_311                11
# emb_312                11
# emb_313                11
# emb_314                11
# emb_315                11
# emb_316                11
# emb_317                11
# emb_318                11
# emb_319                11
# emb_320                11
# emb_321                11
# emb_322                11
# emb_323                11
# emb_324                11
# emb_325                11
# emb_326                11
# emb_327                11
# emb_328                11
# emb_329                11
# emb_330                11
# emb_331                11
# emb_332                11
# emb_333                11
# emb_334                11
# emb_335                11
# emb_336                11
# emb_337                11
# emb_338                11
# emb_339                11
# emb_340                11
# emb_341                11
# emb_342                11
# emb_343                11
# emb_344                11
# emb_345                11
# emb_346                11
# emb_347                11
# emb_348                11
# emb_349                11
# emb_350                11
# emb_351                11
# emb_352                11
# emb_353                11
# emb_354                11
# emb_355                11
# emb_356                11
# emb_357                11
# emb_358                11
# emb_359                11
# emb_360                11
# emb_361                11
# emb_362                11
# emb_363                11
# emb_364                11
# emb_365                11
# emb_366                11
# emb_367                11
# emb_368                11
# emb_369                11
# emb_370                11
# emb_371                11
# emb_372                11
# emb_373                11
# emb_374                11
# emb_375                11
# emb_376                11
# emb_377                11
# emb_378                11
# emb_379                11
# emb_380                11
# emb_381                11
# emb_382                11
# emb_383                11
# emb_384                11
# emb_385                11
# emb_386                11
# emb_387                11
# emb_388                11
# emb_389                11
# emb_390                11
# emb_391                11
# emb_392                11
# emb_393                11
# emb_394                11
# emb_395                11
# emb_396                11
# emb_397                11
# emb_398                11
# emb_399                11
# emb_400                11
# emb_401                11
# emb_402                11
# emb_403                11
# emb_404                11
# emb_405                11
# emb_406                11
# emb_407                11
# emb_408                11
# emb_409                11
# emb_410                11
# emb_411                11
# emb_412                11
# emb_413                11
# emb_414                11
# emb_415                11
# emb_416                11
# emb_417                11
# emb_418                11
# emb_419                11
# emb_420                11
# emb_421                11
# emb_422                11
# emb_423                11
# emb_424                11
# emb_425                11
# emb_426                11
# emb_427                11
# emb_428                11
# emb_429                11
# emb_430                11
# emb_431                11
# emb_432                11
# emb_433                11
# emb_434                11
# emb_435                11
# emb_436                11
# emb_437                11
# emb_438                11
# emb_439                11
# emb_440                11
# emb_441                11
# emb_442                11
# emb_443                11
# emb_444                11
# emb_445                11
# emb_446                11
# emb_447                11
# emb_448                11
# emb_449                11
# emb_450                11
# emb_451                11
# emb_452                11
# emb_453                11
# emb_454                11
# emb_455                11
# emb_456                11
# emb_457                11
# emb_458                11
# emb_459                11
# emb_460                11
# emb_461                11
# emb_462                11
# emb_463                11
# emb_464                11
# emb_465                11
# emb_466                11
# emb_467                11
# emb_468                11
# emb_469                11
# emb_470                11
# emb_471                11
# emb_472                11
# emb_473                11
# emb_474                11
# emb_475                11
# emb_476                11
# emb_477                11
# emb_478                11
# emb_479                11
# emb_480                11
# emb_481                11
# emb_482                11
# emb_483                11
# emb_484                11
# emb_485                11
# emb_486                11
# emb_487                11
# emb_488                11
# emb_489                11
# emb_490                11
# emb_491                11
# emb_492                11
# emb_493                11
# emb_494                11
# emb_495                11
# emb_496                11
# emb_497                11
# emb_498                11
# emb_499                11
# emb_500                11
# emb_501                11
# emb_502                11
# emb_503                11
# emb_504                11
# emb_505                11
# emb_506                11
# emb_507                11
# emb_508                11
# emb_509                11
# emb_510                11
# emb_511                11
#
# We recommend preprocessing discrete columns that can have many values, using 'update_transformers'. Or you may drop columns that are not necessary to model. (Exit this script using ctrl-C)
# PerformanceAlert: Using the CTGANSynthesizer on this data is not recommended. To model this data, CTGAN will generate a large number of columns.
#
# Original Column Name   Est # of Columns (CTGAN)
# disease                2
# emb_0                  11
# emb_1                  11
# emb_2                  11
# emb_3                  11
# emb_4                  11
# emb_5                  11
# emb_6                  11
# emb_7                  11
# emb_8                  11
# emb_9                  11
# emb_10                 11
# emb_11                 11
# emb_12                 11
# emb_13                 11
# emb_14                 11
# emb_15                 11
# emb_16                 11
# emb_17                 11
# emb_18                 11
# emb_19                 11
# emb_20                 11
# emb_21                 11
# emb_22                 11
# emb_23                 11
# emb_24                 11
# emb_25                 11
# emb_26                 11
# emb_27                 11
# emb_28                 11
# emb_29                 11
# emb_30                 11
# emb_31                 11
# emb_32                 11
# emb_33                 11
# emb_34                 11
# emb_35                 11
# emb_36                 11
# emb_37                 11
# emb_38                 11
# emb_39                 11
# emb_40                 11
# emb_41                 11
# emb_42                 11
# emb_43                 11
# emb_44                 11
# emb_45                 11
# emb_46                 11
# emb_47                 11
# emb_48                 11
# emb_49                 11
# emb_50                 11
# emb_51                 11
# emb_52                 11
# emb_53                 11
# emb_54                 11
# emb_55                 11
# emb_56                 11
# emb_57                 11
# emb_58                 11
# emb_59                 11
# emb_60                 11
# emb_61                 11
# emb_62                 11
# emb_63                 11
# emb_64                 11
# emb_65                 11
# emb_66                 11
# emb_67                 11
# emb_68                 11
# emb_69                 11
# emb_70                 11
# emb_71                 11
# emb_72                 11
# emb_73                 11
# emb_74                 11
# emb_75                 11
# emb_76                 11
# emb_77                 11
# emb_78                 11
# emb_79                 11
# emb_80                 11
# emb_81                 11
# emb_82                 11
# emb_83                 11
# emb_84                 11
# emb_85                 11
# emb_86                 11
# emb_87                 11
# emb_88                 11
# emb_89                 11
# emb_90                 11
# emb_91                 11
# emb_92                 11
# emb_93                 11
# emb_94                 11
# emb_95                 11
# emb_96                 11
# emb_97                 11
# emb_98                 11
# emb_99                 11
# emb_100                11
# emb_101                11
# emb_102                11
# emb_103                11
# emb_104                11
# emb_105                11
# emb_106                11
# emb_107                11
# emb_108                11
# emb_109                11
# emb_110                11
# emb_111                11
# emb_112                11
# emb_113                11
# emb_114                11
# emb_115                11
# emb_116                11
# emb_117                11
# emb_118                11
# emb_119                11
# emb_120                11
# emb_121                11
# emb_122                11
# emb_123                11
# emb_124                11
# emb_125                11
# emb_126                11
# emb_127                11
# emb_128                11
# emb_129                11
# emb_130                11
# emb_131                11
# emb_132                11
# emb_133                11
# emb_134                11
# emb_135                11
# emb_136                11
# emb_137                11
# emb_138                11
# emb_139                11
# ...
# emb_84                 11
# emb_85                 11
# emb_86                 11
# emb_87                 11
# emb_88                 11
# emb_89                 11
# emb_90                 11
# emb_91                 11
# emb_92                 11
# emb_93                 11
# emb_94                 11
# emb_95                 11
# emb_96                 11
# emb_97                 11
# emb_98                 11
# emb_99                 11
# emb_100                11
# emb_101                11
# emb_102                11
# emb_103                11
# emb_104                11
# emb_105                11
# emb_106                11
# emb_107                11
# emb_108                11
# emb_109                11
# emb_110                11
# emb_111                11
# emb_112                11
# emb_113                11
# emb_114                11
# emb_115                11
# emb_116                11
# emb_117                11
# emb_118                11
# emb_119                11
# emb_120                11
# emb_121                11
# emb_122                11
# emb_123                11
# emb_124                11
# emb_125                11
# emb_126                11
# emb_127                11
# emb_128                11
# emb_129                11
# emb_130                11
# emb_131                11
# emb_132                11
# emb_133                11
# emb_134                11
# emb_135                11
# emb_136                11
# emb_137                11
# emb_138                11
# emb_139                11
# emb_140                11
# emb_141                11
# emb_142                11
# emb_143                11
# emb_144                11
# emb_145                11
# emb_146                11
# emb_147                11
# emb_148                11
# emb_149                11
# emb_150                11
# emb_151                11
# emb_152                11
# emb_153                11
# emb_154                11
# emb_155                11
# emb_156                11
# emb_157                11
# emb_158                11
# emb_159                11
# emb_160                11
# emb_161                11
# emb_162                11
# emb_163                11
# emb_164                11
# emb_165                11
# emb_166                11
# emb_167                11
# emb_168                11
# emb_169                11
# emb_170                11
# emb_171                11
# emb_172                11
# emb_173                11
# emb_174                11
# emb_175                11
# emb_176                11
# emb_177                11
# emb_178                11
# emb_179                11
# emb_180                11
# emb_181                11
# emb_182                11
# emb_183                11
# emb_184                11
# emb_185                11
# emb_186                11
# emb_187                11
# emb_188                11
# emb_189                11
# emb_190                11
# emb_191                11
# emb_192                11
# emb_193                11
# emb_194                11
# emb_195                11
# emb_196                11
# emb_197                11
# emb_198                11
# emb_199                11
# emb_200                11
# emb_201                11
# emb_202                11
# emb_203                11
# emb_204                11
# emb_205                11
# emb_206                11
# emb_207                11
# emb_208                11
# emb_209                11
# emb_210                11
# emb_211                11
# emb_212                11
# emb_213                11
# emb_214                11
# emb_215                11
# emb_216                11
# emb_217                11
# emb_218                11
# emb_219                11
# emb_220                11
# emb_221                11
# emb_222                11
# emb_223                11
# emb_224                11
# emb_225                11
# emb_226                11
# emb_227                11
# emb_228                11
# emb_229                11
# emb_230                11
# emb_231                11
# emb_232                11
# emb_233                11
# emb_234                11
# emb_235                11
# emb_236                11
# emb_237                11
# emb_238                11
# emb_239                11
# emb_240                11
# emb_241                11
# emb_242                11
# emb_243                11
# emb_244                11
# emb_245                11
# emb_246                11
# emb_247                11
# emb_248                11
# emb_249                11
# emb_250                11
# emb_251                11
# emb_252                11
# emb_253                11
# emb_254                11
# emb_255                11
# emb_256                11
# emb_257                11
# emb_258                11
# emb_259                11
# emb_260                11
# emb_261                11
# emb_262                11
# emb_263                11
# emb_264                11
# emb_265                11
# emb_266                11
# emb_267                11
# emb_268                11
# emb_269                11
# emb_270                11
# emb_271                11
# emb_272                11
# emb_273                11
# emb_274                11
# emb_275                11
# emb_276                11
# emb_277                11
# emb_278                11
# emb_279                11
# emb_280                11
# emb_281                11
# emb_282                11
# emb_283                11
# emb_284                11
# emb_285                11
# emb_286                11
# emb_287                11
# emb_288                11
# emb_289                11
# emb_290                11
# emb_291                11
# emb_292                11
# emb_293                11
# emb_294                11
# emb_295                11
# emb_296                11
# emb_297                11
# emb_298                11
# emb_299                11
# emb_300                11
# emb_301                11
# emb_302                11
# emb_303                11
# emb_304                11
# emb_305                11
# emb_306                11
# emb_307                11
# emb_308                11
# emb_309                11
# emb_310                11
# emb_311                11
# emb_312                11
# emb_313                11
# emb_314                11
# emb_315                11
# emb_316                11
# emb_317                11
# emb_318                11
# emb_319                11
# emb_320                11
# emb_321                11
# emb_322                11
# emb_323                11
# emb_324                11
# emb_325                11
# emb_326                11
# emb_327                11
# emb_328                11
# emb_329                11
# emb_330                11
# emb_331                11
# emb_332                11
# emb_333                11
# emb_334                11
# emb_335                11
# emb_336                11
# emb_337                11
# emb_338                11
# emb_339                11
# emb_340                11
# emb_341                11
# emb_342                11
# emb_343                11
# emb_344                11
# emb_345                11
# emb_346                11
# emb_347                11
# emb_348                11
# emb_349                11
# emb_350                11
# emb_351                11
# emb_352                11
# emb_353                11
# emb_354                11
# emb_355                11
# emb_356                11
# emb_357                11
# emb_358                11
# emb_359                11
# emb_360                11
# emb_361                11
# emb_362                11
# emb_363                11
# emb_364                11
# emb_365                11
# emb_366                11
# emb_367                11
# emb_368                11
# emb_369                11
# emb_370                11
# emb_371                11
# emb_372                11
# emb_373                11
# emb_374                11
# emb_375                11
# emb_376                11
# emb_377                11
# emb_378                11
# emb_379                11
# emb_380                11
# emb_381                11
# emb_382                11
# emb_383                11
# emb_384                11
# emb_385                11
# emb_386                11
# emb_387                11
# emb_388                11
# emb_389                11
# emb_390                11
# emb_391                11
# emb_392                11
# emb_393                11
# emb_394                11
# emb_395                11
# emb_396                11
# emb_397                11
# emb_398                11
# emb_399                11
# emb_400                11
# emb_401                11
# emb_402                11
# emb_403                11
# emb_404                11
# emb_405                11
# emb_406                11
# emb_407                11
# emb_408                11
# emb_409                11
# emb_410                11
# emb_411                11
# emb_412                11
# emb_413                11
# emb_414                11
# emb_415                11
# emb_416                11
# emb_417                11
# emb_418                11
# emb_419                11
# emb_420                11
# emb_421                11
# emb_422                11
# emb_423                11
# emb_424                11
# emb_425                11
# emb_426                11
# emb_427                11
# emb_428                11
# emb_429                11
# emb_430                11
# emb_431                11
# emb_432                11
# emb_433                11
# emb_434                11
# emb_435                11
# emb_436                11
# emb_437                11
# emb_438                11
# emb_439                11
# emb_440                11
# emb_441                11
# emb_442                11
# emb_443                11
# emb_444                11
# emb_445                11
# emb_446                11
# emb_447                11
# emb_448                11
# emb_449                11
# emb_450                11
# emb_451                11
# emb_452                11
# emb_453                11
# emb_454                11
# emb_455                11
# emb_456                11
# emb_457                11
# emb_458                11
# emb_459                11
# emb_460                11
# emb_461                11
# emb_462                11
# emb_463                11
# emb_464                11
# emb_465                11
# emb_466                11
# emb_467                11
# emb_468                11
# emb_469                11
# emb_470                11
# emb_471                11
# emb_472                11
# emb_473                11
# emb_474                11
# emb_475                11
# emb_476                11
# emb_477                11
# emb_478                11
# emb_479                11
# emb_480                11
# emb_481                11
# emb_482                11
# emb_483                11
# emb_484                11
# emb_485                11
# emb_486                11
# emb_487                11
# emb_488                11
# emb_489                11
# emb_490                11
# emb_491                11
# emb_492                11
# emb_493                11
# emb_494                11
# emb_495                11
# emb_496                11
# emb_497                11
# emb_498                11
# emb_499                11
# emb_500                11
# emb_501                11
# emb_502                11
# emb_503                11
# emb_504                11
# emb_505                11
# emb_506                11
# emb_507                11
# emb_508                11
# emb_509                11
# emb_510                11
# emb_511                11
#
# We recommend preprocessing discrete columns that can have many values, using 'update_transformers'. Or you may drop columns that are not necessary to model. (Exit this script using ctrl-C)
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:05<00:00, 100.81it/s]|
# Column Shapes Score: 67.31%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [31:29<00:00, 69.50it/s]|
# Column Pair Trends Score: 88.9%
#
# Overall Score (Average): 78.1%
#
# ctgan - default: quality score = 0.7810
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:04<00:00, 125.70it/s]|
# Column Shapes Score: 66.16%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [1:02:54<00:00, 34.80it/s]|
# Column Pair Trends Score: 88.91%
#
# Overall Score (Average): 77.53%
#
# ctgan - epochs_100: quality score = 0.7753
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:02<00:00, 236.50it/s]|
# Column Shapes Score: 68.09%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [19:29<00:00, 112.25it/s]|
# Column Pair Trends Score: 88.91%
#
# Overall Score (Average): 78.5%
#
# ctgan - epochs_200: quality score = 0.7850
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:01<00:00, 283.67it/s]|
# Column Shapes Score: 67.96%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [21:44<00:00, 100.71it/s]|
# Column Pair Trends Score: 88.89%
#
# Overall Score (Average): 78.42%
#
# ctgan - batch_500: quality score = 0.7842
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:02<00:00, 185.00it/s]|
# Column Shapes Score: 68.11%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [20:13<00:00, 108.20it/s]|
# Column Pair Trends Score: 88.89%
#
# Overall Score (Average): 78.5%
#
# ctgan - batch_1000: quality score = 0.7850
# Best ctgan configuration: batch_1000
# Validation accuracy: 0.9526209677419355
# Validation macro F1: 0.9466040598963552
#
# Classification report:
#
#                       precision    recall  f1-score   support
#
#               Normal       0.97      0.89      0.93       345
# rheumatoid arthritis       0.94      0.99      0.96       647
#
#             accuracy                           0.95       992
#            macro avg       0.96      0.94      0.95       992
#         weighted avg       0.95      0.95      0.95       992
#
#
# === Testing TVAE ===
# C:\Users\ferdi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sdv\single_table\base.py:128: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:02<00:00, 253.01it/s]|
# Column Shapes Score: 86.17%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [12:10<00:00, 179.70it/s]|
# Column Pair Trends Score: 95.06%
#
# Overall Score (Average): 90.61%
#
# tvae - default: quality score = 0.9061
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:01<00:00, 445.14it/s]|
# Column Shapes Score: 87.85%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [12:40<00:00, 172.61it/s]|
# Column Pair Trends Score: 93.29%
#
# Overall Score (Average): 90.57%
#
# tvae - epochs_100: quality score = 0.9057
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:01<00:00, 319.96it/s]|
# Column Shapes Score: 86.57%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [11:47<00:00, 185.66it/s]|
# Column Pair Trends Score: 95.32%
#
# Overall Score (Average): 90.94%
#
# tvae - epochs_200: quality score = 0.9094
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:01<00:00, 460.04it/s]|
# Column Shapes Score: 86.92%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [13:03<00:00, 167.52it/s]|
# Column Pair Trends Score: 95.38%
#
# Overall Score (Average): 91.15%
#
# tvae - batch_500: quality score = 0.9115
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 513/513 [00:02<00:00, 209.37it/s]|
# Column Shapes Score: 85.67%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 131328/131328 [15:54<00:00, 137.53it/s]|
# Column Pair Trends Score: 94.38%
#
# Overall Score (Average): 90.03%
#
# tvae - batch_1000: quality score = 0.9003
# Best tvae configuration: batch_500
# Validation accuracy: 0.9022177419354839
# Validation macro F1: 0.7108784159367817
#
# Classification report:
#
#                       precision    recall  f1-score   support
#
#               Normal       0.76      0.35      0.48       127
# rheumatoid arthritis       0.91      0.98      0.95       865
#
#             accuracy                           0.90       992
#            macro avg       0.83      0.67      0.71       992
#         weighted avg       0.89      0.90      0.89       992

# %%
# Save synthesizer results to files for persistence
import pickle
import os

# Create data directory if it doesn't exist
os.makedirs('data', exist_ok=True)

# Save synthesizer objects and metrics
synthesizer_data = {
    'gc_synth': gc_synth,
    'gc_metrics': gc_metrics,
    'gc_augmented': gc_augmented,
    'ctgan_synth': ctgan_synth,
    'ctgan_metrics': ctgan_metrics,
    'ctgan_augmented': ctgan_augmented,
    'tvae_synth': tvae_synth,
    'tvae_metrics': tvae_metrics,
    'tvae_augmented': tvae_augmented
}

# Save each component separately to avoid memory issues
for key, value in synthesizer_data.items():
    filepath = f'data/{key}.pkl'
    with open(filepath, 'wb') as f:
        pickle.dump(value, f)
    print(f"Saved {key} to {filepath}")

print("\nAll synthesizer data saved successfully!")
# Out:
# Saved gc_synth to data/gc_synth.pkl
# Saved gc_metrics to data/gc_metrics.pkl
# Saved gc_augmented to data/gc_augmented.pkl
# Saved ctgan_synth to data/ctgan_synth.pkl
# Saved ctgan_metrics to data/ctgan_metrics.pkl
# Saved ctgan_augmented to data/ctgan_augmented.pkl
# Saved tvae_synth to data/tvae_synth.pkl
# Saved tvae_metrics to data/tvae_metrics.pkl
# Saved tvae_augmented to data/tvae_augmented.pkl
#
# All synthesizer data saved successfully!

# %%
# Compare all synthesizer results
import matplotlib.pyplot as plt

print("=== SYNTHESIZER COMPARISON ===")
print(f"GaussianCopula - Accuracy: {gc_metrics['accuracy']:.4f}, F1: {gc_metrics['f1_macro']:.4f}")
print(f"CTGAN - Accuracy: {ctgan_metrics['accuracy']:.4f}, F1: {ctgan_metrics['f1_macro']:.4f}")
print(f"TVAE - Accuracy: {tvae_metrics['accuracy']:.4f}, F1: {tvae_metrics['f1_macro']:.4f}")

# Create comparison plot
synthesizers = ['GaussianCopula', 'CTGAN', 'TVAE']
accuracies = [gc_metrics['accuracy'], ctgan_metrics['accuracy'], tvae_metrics['f1_macro']]
f1_scores = [gc_metrics['f1_macro'], ctgan_metrics['f1_macro'], tvae_metrics['f1_macro']]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Accuracy comparison
ax1.bar(synthesizers, accuracies, color=['blue', 'green', 'red'], alpha=0.7)
ax1.set_title('Validation Accuracy Comparison')
ax1.set_ylabel('Accuracy')
ax1.set_ylim(0, 1)
ax1.grid(True, alpha=0.3)

# F1 Score comparison
ax2.bar(synthesizers, f1_scores, color=['blue', 'green', 'red'], alpha=0.7)
ax2.set_title('Validation Macro F1 Comparison')
ax2.set_ylabel('Macro F1')
ax2.set_ylim(0, 1)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Find best synthesizer
best_acc_idx = accuracies.index(max(accuracies))
best_f1_idx = f1_scores.index(max(f1_scores))

print(f"\nBest Accuracy: {synthesizers[best_acc_idx]} ({accuracies[best_acc_idx]:.4f})")
print(f"Best F1 Score: {synthesizers[best_f1_idx]} ({f1_scores[best_f1_idx]:.4f})")
# Out:
# === SYNTHESIZER COMPARISON ===
# GaussianCopula - Accuracy: 0.8347, F1: 0.5558
# CTGAN - Accuracy: 0.9526, F1: 0.9466
# TVAE - Accuracy: 0.9022, F1: 0.7109
# Best Accuracy: CTGAN (0.9526)
# Best F1 Score: CTGAN (0.9466)
